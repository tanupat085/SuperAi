# %% [markdown]
# <a href="https://colab.research.google.com/github/tanupat085/SuperAi/blob/main/22p21s0047_%E0%B8%95%E0%B8%99%E0%B8%B8%E0%B8%A0%E0%B8%B1%E0%B8%97%E0%B8%A3_%E0%B8%82%E0%B9%89%E0%B8%AD_2_18_%E0%B8%81_%E0%B8%A2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx

# %%
G=networkx.Graph()

# %%
G.add_node(1)

# %%
G.add_node(2)

# %%
G.add_node(3)

# %%
G.add_node(4)

# %%
G.add_node(5)

# %%
G.nodes()
# Out:
# NodeView((1, 2, 3, 4, 5))

# %%
G.add_node(6)

# %%
G.add_edge(1,2)

# %%
G.add_edge(2,3)

# %%
G.add_edge(3,4)

# %%
G.add_edge(4,5)

# %%
G.add_edge(5,6)
G.add_edge(1,4)
G.add_edge(2,6)
G.add_edge(3,5)

# %%
G.edges()
# Out:
# EdgeView([(1, 2), (1, 4), (2, 3), (2, 6), (3, 4), (3, 5), (4, 5), (5, 6)])

# %%
import networkx as nx

# %%
nx.draw(G , with_labels=True )

# %%
color_map = []
for node in G:
    if node < 4:
        color_map.append('blue')
    else: 
        color_map.append('green')      
nx.draw(G, node_color=color_map, with_labels=True)
