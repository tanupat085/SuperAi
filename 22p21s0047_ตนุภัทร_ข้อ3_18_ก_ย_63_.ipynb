# %% [markdown]
# <a href="https://colab.research.google.com/github/tanupat085/SuperAi/blob/main/22p21s0047_%E0%B8%95%E0%B8%99%E0%B8%B8%E0%B8%A0%E0%B8%B1%E0%B8%97%E0%B8%A3_%E0%B8%82%E0%B9%89%E0%B8%AD3_18_%E0%B8%81_%E0%B8%A2_63_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U kora
# Out:
# Requirement already up-to-date: kora in /usr/local/lib/python3.6/dist-packages (0.6.14)

# %%
from kora import kaggle
from kora.eda import plot

# %%
from kora import pd

# %%
kaggle.search('sunspot')
# Out:
#                                                  ref  ... downloadCount
# 0                                 robervalt/sunspots  ...          2702
# 1        abhinand05/daily-sun-spot-data-1818-to-2019  ...           208
# 2                                   arasandt/sunspot  ...            51
# 3  davidjackson0513/kanzel-sunspot-data-may-1944-...  ...            29
# 4               sarahvch/yearly-mean-sunspot-numbers  ...           141
# 5      davidjackson0513/sidcsilso-daily-sunspot-data  ...             5
# 6                     hugoherrera11/monthly-sunspots  ...            11
# 7         amoghjrules/sunspotter-14-years-of-sohomdi  ...             0
# 8        dougcresswell/time-series-practice-datasets  ...           339
# 9                                  ujjwal9/o-m-n-i-2  ...           134
#
# [10 rows x 5 columns]

# %%
kaggle.download('robervalt/sunspots')
# Out:
# ...
#   0% 0.00/22.4k [00:00<?, ?B/s]
# 100% 22.4k/22.4k [00:00<00:00, 8.59MB/s]

# %%
test = pd.read_csv('Sunspots.csv')

# %%
plot(test , 'Unnamed: 0' )
# Out:
#   <div class="bk-root" id="b680fca7-e369-44a2-bfb1-fe96e2117d5e" data-root-id="2501"></div>
# <script>(function(root) {
#   function embed_document(root) {
#
# ...

# %%
plot(test , 'Date')
# Out:
#   <div class="bk-root" id="b70eeb8c-26a8-4435-9ca5-b1c63dfc8d10" data-root-id="1741"></div>
# <script>(function(root) {
#   function embed_document(root) {
#
# ...
