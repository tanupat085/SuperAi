# %% [markdown]
# <a href="https://colab.research.google.com/github/tanupat085/SuperAi/blob/main/dept_first_search_my_oat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. เขียน depth-first search พร้อม อนิเมชั่น

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G=nx.Graph()
vertexList = ['0', '1', '2', '3', '4', '5', '6']
for i in range(7):
  G.add_node(i)

G.nodes()
# Out:
# NodeView((0, 1, 2, 3, 4, 5, 6))

# %%
edgeList = [(0,1), (0,2), (1,0) , (1,3) , (2,0) , (2,4) , (2,5) , (3,1), (4,2) , (4,6), (5,2), (6,4)]
for i in edgeList:
  G.add_edge(i[0],i[1])

G.edges()
# Out:
# EdgeView([(0, 1), (0, 2), (1, 3), (2, 4), (2, 5), (4, 6)])

# %%
graphs = (vertexList, edgeList)

def dfs(graph, start):
    vertexList, edgeList = graph
    visitedVertex = []
    stack = [start]
    adjacencyList = [[] for vertex in vertexList]

    for edge in edgeList:
        adjacencyList[edge[0]].append(edge[1])

    # for node
    AnimationGraph(visitedVertex)

    while stack:
        current = stack.pop()
        for neighbor in adjacencyList[current]:
            if not neighbor in visitedVertex:
                stack.append(neighbor)
        visitedVertex.append(current)

        AnimationGraph(visitedVertex)

    return visitedVertex
  
def AnimationGraph(visitedVertex):
    color_map = []
    for node in G:
      if node in visitedVertex:
          color_map.append('green')
      else:
          color_map.append('blue')

    if len(visitedVertex) > 0:
        print(f"\n {visitedVertex} \n")
    else:
        print("\n Start \n")

    nx.draw(G, node_color=color_map, with_labels=True)
    plt.show()
  

print(dfs(graphs, 0))
# Out:
#  Start
#  [0]
#  [0, 2]
#  [0, 2, 5]
#  [0, 2, 5, 4]
#  [0, 2, 5, 4, 6]
#  [0, 2, 5, 4, 6, 1]
#  [0, 2, 5, 4, 6, 1, 3]
# [0, 2, 5, 4, 6, 1, 3]
